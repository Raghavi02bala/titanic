# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
train = pd.read_csv("../input/titanic/train.csv")
test  = pd.read_csv("../input/titanic/test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['O'])
# The Cabin top should return C23 C25 C27, but it's not returning that value.
# Out:
#                                              Name   Sex    Ticket  \
# count                                         891   891       891
# unique                                        891     2       681
# top     Stone, Mrs. George Nelson (Martha Evelyn)  male  CA. 2343
# freq                                            1   577         7
#
#               Cabin Embarked
# count           204      889
# unique          147        3
# top     C23 C25 C27        S
# freq              4      644

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.shape
# Out:
# (418, 11)

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# Features vs Survival Relationship.

# %%
survived  = train.loc[train['Survived'] == 1]
# not_survived = 891 - len(survived)
# len(survived)
not_survived = train[train['Survived'] == 0]
# len(not_survived)

# python formatters.formatting using modulo operators.
print ("Survived: %i (%.1f%%)"%(len(survived), len(survived)/len(train)*100.0))
# the float(100) is same as 100, does not make any change in the O/P
print("Not Survived: %i (%.1f%%)"%(len(not_survived), float(100)-(len(survived)/len(train)*100.0)))
print("Total %i"%len(train))
# Out:
# Survived: 342 (38.4%)
# Not Survived: 549 (61.6%)
# Total 891

# %% [markdown]
# **Pclass vs. Survival**
# Higher class passengers have better survival chance.

# %%
train.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train.groupby('Pclass').Survived.value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
sns.barplot(x='Pclass', y='Survived', data=train)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train.groupby('Sex').Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.barplot(x='Sex', y='Survived', data=train)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# # Pclass and Sex vs Survival

# %%
tab  = pd.crosstab(train['Pclass'], train['Sex'])
print(tab)

tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.xlabel('Pclass')
plt.ylabel('Percentage')
# tab.sum(1)

# The bar plot will show the survival rate of female and male in each class seperately.
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347
# Text(0, 0.5, 'Percentage')

# %%
sns.factorplot('Sex', 'Survived', hue='Pclass', size=4, aspect=2, data=train)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex',col='Embarked', size=4, aspect=2, data=train)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Embarked vs. Survived

# %%
train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.groupby('Embarked').Survived.value_counts()
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: Survived, dtype: int64

# %%
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean()
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
sns.barplot(x='Embarked', y='Survived', data=train)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Survived'>

# %% [markdown]
# # Parch Vs survival

# %%
train.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
train.groupby('Parch').Survived.value_counts()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
train[['Parch', 'Survived']].groupby(['Parch'], as_index=False).mean()
# Out:
#    Parch  Survived
# 0      0  0.343658
# 1      1  0.550847
# 2      2  0.500000
# 3      3  0.600000
# 4      4  0.000000
# 5      5  0.200000
# 6      6  0.000000

# %%
sns.barplot(x='Parch', y='Survived',ci=None, data=train)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %% [markdown]
# # SibSp vs. Survival

# %%
train.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
train.groupby('SibSp').Survived.value_counts()
# Out:
# SibSp  Survived
# 0      0           398
#        1           210
# 1      1           112
#        0            97
# 2      0            15
#        1            13
# 3      0            12
#        1             4
# 4      0            15
#        1             3
# 5      0             5
# 8      0             7
# Name: Survived, dtype: int64

# %%
train[['SibSp', 'Survived']].groupby('SibSp').Survived.mean()
# Out:
# SibSp
# 0    0.345395
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: Survived, dtype: float64

# %%
sns.barplot(x='SibSp', y='Survived',ci=None, data=train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %% [markdown]
# # Age Vs Survival

# %%
train.Age.value_counts().tail(5)
# Out:
# 55.50    1
# 74.00    1
# 0.92     1
# 70.50    1
# 12.00    1
# Name: Age, dtype: int64

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

sns.violinplot(x='Embarked', y='Age', hue='Survived', data=train, split=True, ax=ax1)
sns.violinplot(x='Pclass', y='Age', hue='Survived', data=train,split=True, ax=ax2)
sns.violinplot(x='Sex',y='Age', hue='Survived', data=train,split=True, ax=ax3)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
total_survived = train[train.Survived==1]
total_not_survived = train[train.Survived==0]
male_survived = train[(train['Survived']==1) & (train['Sex']=='male')]
female_survived = train[(train['Survived']==1) & (train['Sex']=='female')]
male_not_survived = train[(train['Survived']==0) & (train['Sex']=='male')]
female_not_survived = train[(train['Survived']==0) & (train['Sex']=='female')]

plt.figure(figsize=(15,5))

plt.subplot(111)
sns.histplot(total_survived['Age'].dropna().values, bins=range(0, 81, 1), color='blue')
sns.histplot(total_not_survived['Age'].dropna().values, bins=range(0, 81, 1), color='red')
plt.xlabel('Age')

plt.figure(figsize=(15,5))

plt.subplot(121)
sns.histplot(female_survived['Age'].dropna().values, bins=range(0, 81, 1))
sns.histplot(female_not_survived['Age'].dropna().values, bins=range(0, 81, 1), color='red')
plt.xlabel('Female Age')

plt.subplot(122)
sns.histplot(male_survived['Age'].dropna().values, bins=range(0, 81, 1))
sns.histplot(male_not_survived['Age'].dropna().values, bins=range(0, 81, 1), color='red')
plt.xlabel('Male Age')
# Out:
# Text(0.5, 0, 'Male Age')

# %% [markdown]
# **Correlating Features**

# %% [markdown]
# We have to find the positive and negative correlation of fetures with survive

# %%
plt.figure(figsize=(15,5))
sns.heatmap(train.drop('PassengerId',axis=1).corr(), vmax=0.6, square=True, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Feature Extraction**

# %%
train_test_data = [train, test]

for dataset in train_test_data:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.')

# %%
pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
train[['Title', 'Survived']].groupby('Title', as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4   Other  0.347826

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Other": 5}
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      2
# 3      0            113803  53.1000  C123        S      3
# ...

# %% [markdown]
# **Sex Feature**

# %%
for dataset in train_test_data:
    dataset.Sex = dataset.Sex.map({'female': 1,  'male': 0})

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      1
# 1          PC 17599  71.2833   C85        C      3
# 2  STON/O2. 3101282   7.9250   NaN        S      2
# 3            113803  53.1000  C123        S      3
# ...

# %% [markdown]
# **Embarked Feature**

# %%
train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      1
# 1          PC 17599  71.2833   C85        C      3
# 2  STON/O2. 3101282   7.9250   NaN        S      2
# 3            113803  53.1000  C123        S      3
# ...

# %%
print(dataset.Embarked.unique())
# Out:
# ['Q' 'S' 'C']

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} )

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked         int64
# Title            int64
# dtype: object

# %% [markdown]
# **Age Feature**

# %% [markdown]
# We first fill the NULL values of Age with a random number between (mean_age - std_age) and (mean_age + std_age).
#
# We then create a new column named AgeBand. This categorizes age into 5 different age range.

# %%
for dataset in train_test_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()
    
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    dataset['Age'][np.isnan(dataset['Age'])] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)
    
train['AgeBand'] = pd.cut(train['Age'], 5)

print (train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean())
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.508772
# 1   (16.0, 32.0]  0.364465
# 2   (32.0, 48.0]  0.360465
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket     Fare Cabin  Embarked  Title       AgeBand
# 0         A/5 21171   7.2500   NaN         0      1  (16.0, 32.0]
# 1          PC 17599  71.2833   C85         1      3  (32.0, 48.0]
# 2  STON/O2. 3101282   7.9250   NaN         0      2  (16.0, 32.0]
# ...

# %%
for dataset in train_test_data:
    dataset.loc[dataset['Age'] <= 16, 'Age'] = 0    
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1    2      1      0
# 2                             Heikkinen, Miss. Laina    1    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1    2      1      0
# 4                           Allen, Mr. William Henry    0    2      0      0
#
#              Ticket     Fare Cabin  Embarked  Title       AgeBand
# 0         A/5 21171   7.2500   NaN         0      1  (16.0, 32.0]
# 1          PC 17599  71.2833   C85         1      3  (32.0, 48.0]
# 2  STON/O2. 3101282   7.9250   NaN         0      2  (16.0, 32.0]
# ...

# %% [markdown]
# **Fare Feature**
#
# Replace missing Fare values with median of Fare

# %%
for dataset in train_test_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

# %%
train['FareBand'] = pd.qcut(train['Fare'], 4)
print(train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean())
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
train.FareBand.unique()
# Out:
# [(-0.001, 7.91], (31.0, 512.329], (7.91, 14.454], (14.454, 31.0]]
# Categories (4, interval[float64]): [(-0.001, 7.91] < (7.91, 14.454] < (14.454, 31.0] < (31.0, 512.329]]

# %%
for dataset in train_test_data:
    dataset.loc[dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31.0), 'Fare'] = 2
    dataset.loc[dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1    2      1      0
# 2                             Heikkinen, Miss. Laina    1    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1    2      1      0
# 4                           Allen, Mr. William Henry    0    2      0      0
#
#              Ticket  Fare Cabin  Embarked  Title       AgeBand  \
# 0         A/5 21171     0   NaN         0      1  (16.0, 32.0]
# 1          PC 17599     3   C85         1      3  (32.0, 48.0]
# 2  STON/O2. 3101282     1   NaN         0      2  (16.0, 32.0]
# ...

# %% [markdown]
# **SibSp & Parch Feature**
#
# Combining SibSp & Parch feature, we create a new feature named FamilySize.

# %%
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
    
print(train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).Survived.mean())
# Out:
#    FamilySize  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in train_test_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
print(train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean())
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  Sex  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris    0    1      1
#
#    Parch     Ticket  Fare Cabin  Embarked  Title       AgeBand  \
# 0      0  A/5 21171     0   NaN         0      1  (16.0, 32.0]
#
#          FareBand  FamilySize  IsAlone
# 0  (-0.001, 7.91]           2        0

# %%
test.head(1)
# Out:
#    PassengerId  Pclass              Name  Sex  Age  SibSp  Parch  Ticket  \
# 0          892       3  Kelly, Mr. James    0    2      0      0  330911
#
#    Fare Cabin  Embarked  Title  FamilySize  IsAlone
# 0     0   NaN         2      1           1        1

# %% [markdown]
# **Feature Selection**
#
# Determining which features should be used to train the model

# %%
drop_features = ['Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'FamilySize']
train = train.drop(drop_features, axis=1)
test  = test.drop(drop_features, axis=1)
train = train.drop(['PassengerId', 'AgeBand', 'FareBand'], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone
# 0         0       3    0    1     0         0      1        0
# 1         1       1    1    2     3         1      3        0
# 2         1       3    1    1     1         0      2        1
# 3         1       1    1    2     3         0      3        0
# 4         0       3    0    2     1         0      1        1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone
# 0          892       3    0    2     0         2      1        1
# 1          893       3    1    2     0         0      3        0
# 2          894       2    0    3     1         2      1        1
# 3          895       3    0    1     1         0      1        1
# 4          896       3    1    1     1         0      3        0

# %% [markdown]
# **Classification & Accuracy**

# %%
X_train = train.drop('Survived', axis=1)
y_train = train['Survived']
X_test  = test.drop("PassengerId", axis=1).copy()

X_train.shape, y_train.shape, X_test.shape
# Out:
# ((891, 7), (891,), (418, 7))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# **Logistic Regression**

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_predict_log_reg = clf.predict(X_test)
# score => Return the mean accuracy on the given test data and labels.
accuracy_log_reg  = round(clf.score(X_train, y_train) * 100, 2)
print (str(accuracy_log_reg) + ' percent')
# Out:
# 80.36 percent

# %% [markdown]
# **Support Vector Machine (SVM)**

# %%
clf = SVC()
clf.fit(X_train, y_train)
y_predict_svc = clf.predict(X_test)
accuracy_svc = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_svc)
# Out:
# 82.83

# %% [markdown]
# **Linear SVM**

# %%
clf = LinearSVC()
clf.fit(X_train, y_train)
y_predict_linear_svc = clf.predict(X_test)
accuracy_linear_svc = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_linear_svc)
# Out:
# 79.35
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# **k -Nearest Neighbors**

# %%
clf = KNeighborsClassifier(n_neighbors = 3)
clf.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
accuracy_knn = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_knn)
# Out:
# 79.8

# %% [markdown]
# **Decision Tree**

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred_decision_tree = clf.predict(X_test)
accuracy_decision_tree = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_decision_tree)
# Out:
# 87.21

# %% [markdown]
# **Random Forest**

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest = clf.predict(X_test)
accuracy_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_random_forest)
# Out:
# 87.21

# %% [markdown]
# **Gaussian Naive Bayes**

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred_gnb = clf.predict(X_test)
accuracy_gnb = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_gnb)
# Out:
# 77.67

# %% [markdown]
# **Perceptron**

# %%
clf = Perceptron(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_perceptron = clf.predict(X_test)
accuracy_perceptron = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_perceptron)
# Out:
# 76.43

# %% [markdown]
# **Stochastic Gradient Descent (SGD)**

# %%
clf = SGDClassifier(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_sgd = clf.predict(X_test)
accuracy_sgd = round(clf.score(X_train, y_train) * 100, 2)
print (accuracy_sgd)
# Out:
# 64.42

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
import itertools

clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest_training_set = clf.predict(X_train)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print ("Accuracy: %i %% \n"%acc_random_forest)

class_names = ['Survived', 'Not Survived']

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_train, y_pred_random_forest_training_set)
np.set_printoptions(precision=2)

print ('Confusion Matrix in Numbers')
print (cnf_matrix)
print ('')

cnf_matrix_percent = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]

print ('Confusion Matrix in Percentage')
print (cnf_matrix_percent)
print ('')

true_class_names = ['True Survived', 'True Not Survived']
predicted_class_names = ['Predicted Survived', 'Predicted Not Survived']

df_cnf_matrix = pd.DataFrame(cnf_matrix, 
                             index = true_class_names,
                             columns = predicted_class_names)

df_cnf_matrix_percent = pd.DataFrame(cnf_matrix_percent, 
                                     index = true_class_names,
                                     columns = predicted_class_names)

plt.figure(figsize = (15,5))

plt.subplot(121)
sns.heatmap(df_cnf_matrix, annot=True, fmt='d')

plt.subplot(122)
sns.heatmap(df_cnf_matrix_percent, annot=True)
# Out:
# Accuracy: 87 %
#
# Confusion Matrix in Numbers
# [[514  35]
#  [ 79 263]]
#
# Confusion Matrix in Percentage
# [[0.94 0.06]
#  [0.23 0.77]]
# <AxesSubplot:>

# %% [markdown]
# Comparing Accuracy of all models.

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Support Vector Machines', 'Linear SVC', 
              'KNN', 'Decision Tree', 'Random Forest', 'Naive Bayes', 
              'Perceptron', 'Stochastic Gradient Decent'],
    
    'Score': [accuracy_log_reg, accuracy_svc, accuracy_linear_svc, 
              accuracy_knn,  accuracy_decision_tree, accuracy_random_forest, accuracy_gnb, 
              accuracy_perceptron, accuracy_sgd]
    })

models.sort_values(by='Score', ascending=False)
# Out:
#                         Model  Score
# 4               Decision Tree  87.21
# 5               Random Forest  87.21
# 1     Support Vector Machines  82.83
# 0         Logistic Regression  80.36
# 3                         KNN  79.80
# 2                  Linear SVC  79.35
# 6                 Naive Bayes  77.67
# 7                  Perceptron  76.43
# 8  Stochastic Gradient Decent  64.42

# %% [markdown]
# **Final Result**
#
# From the given results we can observe that Decision Tree and Random Forest Classifiers give us the highest accuracy.
#
# Among these two, we choose Random Forest classifier as it has the ability to limit overfitting as compared to Decision Tree classifier.

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone
# 0          892       3    0    2     0         2      1        1
# 1          893       3    1    2     0         0      3        0
# 2          894       2    0    3     1         2      1        1
# 3          895       3    0    1     1         0      1        1
# 4          896       3    1    1     1         0      3        0

# %% [markdown]
# Creating a Submission file to kaggle.

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": y_pred_random_forest
    })
